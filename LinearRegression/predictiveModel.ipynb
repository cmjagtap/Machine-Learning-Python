# %%
#Predict prices of houses using scikit-learn Linear Regression model
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

df = pd.read_csv("house_Data.csv")

# %%
# %matplotlib inline
plt.xlabel("Area of Houses in Square Meters")
plt.ylabel("Prices in Lakhs")
plt.plot(df.Area,df.SalePrice,marker="+")

# %%
# regObj = linear_model.LinearRegression()
regObj.fit(df[['Area']],df.SalePrice)
regObj.predict(1935) #find a price for 1935 area
# Out:
# array([208532.60150185])

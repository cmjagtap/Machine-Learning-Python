# %%
import pandas as pd
import numpy as np
df = pd.read_csv("kotak.csv",parse_dates=["Date"],index_col="Date")
df["2017-02":"2017-04"]
# Out:
#                Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-02-01  KOTAKBANK     EQ      774.15      777.50      782.95     739.15
# 2017-02-02  KOTAKBANK     EQ      777.05      779.00      780.45     764.45
# 2017-02-03  KOTAKBANK     EQ      770.40      769.50      777.20     760.00
# 2017-02-06  KOTAKBANK     EQ      765.30      770.00      773.75     765.30
# 2017-02-07  KOTAKBANK     EQ      766.70      769.00      784.95     768.50
# 2017-02-08  KOTAKBANK     EQ      773.35      774.40      776.20     762.00
# 2017-02-09  KOTAKBANK     EQ      767.60      769.90      779.50     765.00
# 2017-02-10  KOTAKBANK     EQ      769.65      771.10      786.30     771.10
# 2017-02-13  KOTAKBANK     EQ      778.90      779.80      796.00     779.50
# 2017-02-14  KOTAKBANK     EQ      793.15      793.90      796.35     785.95
# 2017-02-15  KOTAKBANK     EQ      790.30      791.20      795.00     781.75
# ...

# %%
# %matplotlib inline
df[['Close Price','Open Price','High Price']].plot()
